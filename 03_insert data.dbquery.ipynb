-- %%
USE CATALOG employee_management;

USE SCHEMA fullstack;


CREATE TABLE employee_management.fullstack.employees (
  ID INT,
  `First_Name` STRING,
  `Last_Name` STRING,
  Email STRING,
  Phone STRING,
  Department STRING,
  Designation STRING,
  Salary INT,
  Joined DATE,
  Status STRING
);
