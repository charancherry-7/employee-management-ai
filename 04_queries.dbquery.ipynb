-- %%
USE CATALOG employee_management;

USE SCHEMA fullstack;

--SELECT COUNT(*) FROM employee_management.fullstack.employees;

--SELECT * FROM employees;

--LIST '/Volumes/employee_management/fullstack/general_docs';
LIST '/Volumes/employee_management/fullstack/restricted_docs';
